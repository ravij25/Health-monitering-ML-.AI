# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'D:\AI\python\Python course\Data_science\imp\work\vLife_case_Virtusa\vLife_case_Virtusa.csv')
# Out:
# C:\Users\admn\AppData\Local\Temp\ipykernel_1824\2618643656.py:1: DtypeWarning: Columns (2,6,10,11,13,14,16,17,18,20,21,22,23,24,25,26,28,33,45,49,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r'D:\AI\python\Python course\Data_science\imp\work\vLife_case_Virtusa\vLife_case_Virtusa.csv')

# %%
df.head()
# Out:
#     ID   Score Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0  1.0   918.0         A       36.0     3000.0       14.4  UnSecured
# 1  3.0   903.0         A      120.0    21000.0        7.9  secured
# 2  4.0  1060.0         X       78.0     7200.0        7.9  secured
# 3  6.0   839.0         B       60.0     8000.0       16.9  UnSecured
# 4  7.0  1057.0         X       60.0     7650.0        7.4  UnSecured
#
#    Feature_6  Class  Feature_7  ... Feature_32 Feature_33  Feature_34  \
# 0       46.0    8.0      132.0  ...        0.0        9.0        10.0
# 1       16.0    3.0      288.0  ...        0.0        6.0        22.0
# 2       17.0    3.0      276.0  ...        0.0        1.0        21.0
# 3       47.0    8.0       48.0  ...        0.0        5.0         0.0
# 4       55.0   10.0      156.0  ...        0.0        1.0        13.0
#
#   Feature_35 Feature_36  Feature_37 Feature_38 Feature_38.1 Feature_39  \
# ...

# %%
df.describe()
# Out:
#                  ID         Score     Feature_2     Feature_3     Feature_4  \
# count  16383.000000  16383.000000  16383.000000  16383.000000  16383.000000
# mean   21168.695294    882.061832     59.142892   7364.007758     18.754587
# std    12142.797527     93.149605     26.689123   6673.343595      9.662504
# min        1.000000    352.000000      6.000000    500.000000      0.000000
# 25%    10699.000000    818.000000     48.000000   3000.000000      9.900000
# 50%    21303.000000    882.000000     60.000000   5300.000000     16.900000
# 75%    31689.000000    947.000000     60.000000   9000.000000     24.900000
# max    42072.000000   1295.000000    300.000000  75000.000000     50.400000
#
#           Feature_6         Class     Feature_7     Feature_8   Employement  \
# count  16383.000000  16383.000000  16383.000000  16383.000000  16383.000000
# mean      29.419703      5.352683    120.488128      0.808460    103.096075
# ...

# %%
df.dtypes
# Out:
# ID              float64
# Score           float64
# Feature_1        object
# Feature_2       float64
# Feature_3       float64
# Feature_4       float64
# Feature_5        object
# Feature_6       float64
# Class           float64
# Feature_7       float64
# Staus            object
# Indicator        object
# Feature_8       float64
# Feature_9        object
# Gender           object
# Employement     float64
# Feature_10       object
# Feature_11       object
# Feature_12       object
# Range           float64
# Feature_14       object
# Feature_15       object
# Feature_16       object
# Feature_17       object
# Feature_18       object
# Feature_19       object
# Feature_20       object
# Time            float64
# Value            object
# Balance         float64
# Feature_21      float64
# Feature_22      float64
# Feature_23      float64
# Feature_24       object
# Age             float64
# Feature_25      float64
# Feature_26      float64
# Feature_27      float64
# ...

# %%
df.Target.unique
# Out:
# <bound method Series.unique of 0             NaN
# 1        Critical
# 2           Joint
# 3        Critical
# 4          Single
#            ...
# 16381      Single
# 16382         NaN
# 16383         NaN
# 16384         NaN
# 16385         NaN
# Name: Target, Length: 16386, dtype: object>

# %% [markdown]
# # Pie chart for Target class

# %%
class_counts = df['Target'].value_counts()

# Create a pie chart
plt.pie(class_counts, labels=class_counts.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Class Distribution')
plt.show()

# %% [markdown]
# from above figure taarget category single is high which is 66.2 % and next rank critical which is 20.8% and ref is 6.4 % and joint is 6.1%

# %%
counts = df['Target'].value_counts()

# Creating a bar chart
counts.plot.bar()

# Setting the axis labels and title
plt.xlabel('fatures')
plt.ylabel('Count')
plt.title(' Distribution Target')
plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # Visulazation of Independet variable vs Target

# %%
# Count the frequency of target categories for each independent category
counts = df.groupby('Age')['Target'].value_counts().unstack(fill_value=0)

# Create a stacked bar chart
counts.plot(kind='bar', stacked=True)

# Add title and labels
plt.title('Target categorical variable by independent column')
plt.xlabel('Independent column')
plt.ylabel('Count')
plt.figure(figsize=(8, 10))
# Show plot
plt.show()

# %% [markdown]
# for all target category from age 30 to 60 years  is high

# %%
# Count the frequency of target categories for each independent category
counts = df.groupby('Gender')['Target'].value_counts().unstack(fill_value=0)

# Create a stacked bar chart
counts.plot(kind='bar', stacked=True)

# Add title and labels
plt.title('Target categorical variable by independent column')
plt.xlabel('Gender')
plt.ylabel('Count')

# Show plot
plt.show()

# %% [markdown]
# from the above graph gender 2 category prone high risk

# %%
# Count the frequency of target categories for each independent category
counts = df.groupby('Employement')['Target'].value_counts().unstack(fill_value=0)

# Create a stacked bar chart
counts.plot(kind='bar', stacked=True)

# Add title and labels
plt.title('Target categorical variable by independent column')
plt.xlabel('Independent column')
plt.ylabel('Count')

# Show plot
plt.show()

# %%
# Count the frequency of target categories for each independent category
counts = df.groupby('Time')['Target'].value_counts().unstack(fill_value=0)

# Create a stacked bar chart
counts.plot(kind='bar', stacked=True)

# Add title and labels
plt.title('Target categorical variable by independent column')
plt.xlabel('Time')
plt.ylabel('Count')

# Show plot
plt.show()

# %%
# Count the frequency of target categories for each independent category
counts = df['Target'].value_counts()

# Create a bar chart
plt.bar(counts.index, counts.values)

# Add title and labels
plt.title('Target categorical variable by independent column')
plt.xlabel('Target category')
plt.ylabel('Count')

# Show plot
plt.show()

# %%
df = df.fillna(df.mode().iloc[0])

print(df)
# Out:
#             ID   Score Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0          1.0   918.0         A       36.0     3000.0       14.4  UnSecured
# 1          3.0   903.0         A      120.0    21000.0        7.9  secured
# 2          4.0  1060.0         X       78.0     7200.0        7.9  secured
# 3          6.0   839.0         B       60.0     8000.0       16.9  UnSecured
# 4          7.0  1057.0         X       60.0     7650.0        7.4  UnSecured
# ...        ...     ...       ...        ...        ...        ...        ...
# 16381  42070.0   790.0         D       36.0     3000.0       25.9  UnSecured
# 16382  42072.0   905.0         A       60.0     8460.0        7.9  UnSecured
# 16383      1.0   896.0         A       60.0     5000.0        7.9  UnSecured
# 16384      1.0   896.0         A       60.0     5000.0        7.9  UnSecured
# 16385      1.0   896.0         A       60.0     5000.0        7.9  UnSecured
#
# ...

# %%
#Label Encoder
from sklearn.preprocessing import LabelEncoder
  
# label_encoder object knows how to understand word labels.
le = LabelEncoder()
  
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = le.fit_transform(df[col])

# %% [markdown]
# # correlation

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), cmap="viridis",annot=True,linewidths=0.1)
# Out:
# <AxesSubplot:>

# %%
df.isnull()
# Out:
#           ID  Score  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0      False  False      False      False      False      False      False
# 1      False  False      False      False      False      False      False
# 2      False  False      False      False      False      False      False
# 3      False  False      False      False      False      False      False
# 4      False  False      False      False      False      False      False
# ...      ...    ...        ...        ...        ...        ...        ...
# 16381  False  False      False      False      False      False      False
# 16382  False  False      False      False      False      False      False
# 16383  False  False      False      False      False      False      False
# 16384  False  False      False      False      False      False      False
# 16385  False  False      False      False      False      False      False
#
# ...

# %% [markdown]
# # Mode values for filling the null values
#
# Mode is  best suitable for filling the missing values categorical values

# %%
# fill null values with the mode value
df.fillna(df.mode().iloc[0], inplace=True)
print(df)
# Out:
#             ID   Score  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0          1.0   918.0          0       36.0     3000.0       14.4          0
# 1          3.0   903.0          0      120.0    21000.0        7.9          1
# 2          4.0  1060.0          9       78.0     7200.0        7.9          1
# 3          6.0   839.0          1       60.0     8000.0       16.9          0
# 4          7.0  1057.0          9       60.0     7650.0        7.4          0
# ...        ...     ...        ...        ...        ...        ...        ...
# 16381  42070.0   790.0          3       36.0     3000.0       25.9          0
# 16382  42072.0   905.0          0       60.0     8460.0        7.9          0
# 16383      1.0   896.0          0       60.0     5000.0        7.9          0
# 16384      1.0   896.0          0       60.0     5000.0        7.9          0
# 16385      1.0   896.0          0       60.0     5000.0        7.9          0
#
# ...

# %%
df.Target.unique
# Out:
# <bound method Series.unique of 0        4
# 1        1
# 2        3
# 3        1
# 4        4
#         ..
# 16381    4
# 16382    4
# 16383    4
# 16384    4
# 16385    4
# Name: Target, Length: 16386, dtype: int32>

# %%
# Reading first first five rows afte filling null values

df.head()
# Out:
#     ID   Score  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0  1.0   918.0          0       36.0     3000.0       14.4          0
# 1  3.0   903.0          0      120.0    21000.0        7.9          1
# 2  4.0  1060.0          9       78.0     7200.0        7.9          1
# 3  6.0   839.0          1       60.0     8000.0       16.9          0
# 4  7.0  1057.0          9       60.0     7650.0        7.4          0
#
#    Feature_6  Class  Feature_7  ...  Feature_32  Feature_33  Feature_34  \
# 0       46.0    8.0      132.0  ...         0.0         9.0        10.0
# 1       16.0    3.0      288.0  ...         0.0         6.0        22.0
# 2       17.0    3.0      276.0  ...         0.0         1.0        21.0
# 3       47.0    8.0       48.0  ...         0.0         5.0         0.0
# 4       55.0   10.0      156.0  ...         0.0         1.0        13.0
#
#    Feature_35  Feature_36  Feature_37  Feature_38  Feature_38.1  Feature_39  \
# ...

# %%
# finding is threre any null values still
df.isnull().sum()
# Out:
# ID              0
# Score           0
# Feature_1       0
# Feature_2       0
# Feature_3       0
# Feature_4       0
# Feature_5       0
# Feature_6       0
# Class           0
# Feature_7       0
# Staus           0
# Indicator       0
# Feature_8       0
# Feature_9       0
# Gender          0
# Employement     0
# Feature_10      0
# Feature_11      0
# Feature_12      0
# Range           0
# Feature_14      0
# Feature_15      0
# Feature_16      0
# Feature_17      0
# Feature_18      0
# Feature_19      0
# Feature_20      0
# Time            0
# Value           0
# Balance         0
# Feature_21      0
# Feature_22      0
# Feature_23      0
# Feature_24      0
# Age             0
# Feature_25      0
# Feature_26      0
# Feature_27      0
# Feature_28      0
# Feature_29      0
# Feature_30      0
# Feature_31      0
# Feature_32      0
# Feature_33      0
# Feature_34      0
# Feature_35      0
# Feature_36      0
# Feature_37      0
# Feature_38      0
# Feature_38.1    0
# ...

# %% [markdown]
# from the above confirming that the data set contains null values

# %%
from sklearn.preprocessing import LabelEncoder
  
# label_encoder object knows how to understand word labels.
le = LabelEncoder()
  
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = le.fit_transform(df[col])

# %%
# print the encoded dataframe
print(df)
# Out:
#             ID   Score  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0          1.0   918.0          0       36.0     3000.0       14.4          0
# 1          3.0   903.0          0      120.0    21000.0        7.9          1
# 2          4.0  1060.0          9       78.0     7200.0        7.9          1
# 3          6.0   839.0          1       60.0     8000.0       16.9          0
# 4          7.0  1057.0          9       60.0     7650.0        7.4          0
# ...        ...     ...        ...        ...        ...        ...        ...
# 16381  42070.0   790.0          3       36.0     3000.0       25.9          0
# 16382  42072.0   905.0          0       60.0     8460.0        7.9          0
# 16383      1.0   896.0          0       60.0     5000.0        7.9          0
# 16384      1.0   896.0          0       60.0     5000.0        7.9          0
# 16385      1.0   896.0          0       60.0     5000.0        7.9          0
#
# ...

# %%
df.Target.unique()
# Out:
# array([4, 1, 3, 0, 2])

# %%
# visulizing data 
plt.figure(figsize=(50,30))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.dropna()
# Out:
#             ID   Score  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0          1.0   918.0          0       36.0     3000.0       14.4          0
# 1          3.0   903.0          0      120.0    21000.0        7.9          1
# 2          4.0  1060.0          9       78.0     7200.0        7.9          1
# 3          6.0   839.0          1       60.0     8000.0       16.9          0
# 4          7.0  1057.0          9       60.0     7650.0        7.4          0
# ...        ...     ...        ...        ...        ...        ...        ...
# 16381  42070.0   790.0          3       36.0     3000.0       25.9          0
# 16382  42072.0   905.0          0       60.0     8460.0        7.9          0
# 16383      1.0   896.0          0       60.0     5000.0        7.9          0
# 16384      1.0   896.0          0       60.0     5000.0        7.9          0
# 16385      1.0   896.0          0       60.0     5000.0        7.9          0
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
# create a StandardScaler object
scaler = StandardScaler()

# fit and transform the dataframe
df_scaled = scaler.fit_transform(df)

# convert the scaled data to a dataframe
df_scaled = pd.DataFrame(df_scaled, columns=df.columns)

# print the scaled dataframe
print(df_scaled)
# Out:
#              ID     Score  Feature_1  Feature_2  Feature_3  Feature_4  \
# 0     -1.742639  0.385830  -1.021435  -0.867240  -0.653954  -0.450466
# 1     -1.742475  0.224780  -1.021435   2.280494   2.043643  -1.123174
# 2     -1.742392  1.910443   1.510035   0.706627  -0.024514  -1.123174
# 3     -1.742228 -0.462370  -0.740161   0.032113   0.095379  -0.191732
# 4     -1.742145  1.878232   1.510035   0.032113   0.042926  -1.174921
# ...         ...       ...        ...        ...        ...        ...
# 16381  1.721343 -0.988468  -0.177612  -0.867240  -0.653954   0.739710
# 16382  1.721508  0.246253  -1.021435   0.032113   0.164317  -1.123174
# 16383 -1.742639  0.149623  -1.021435   0.032113  -0.354221  -1.123174
# 16384 -1.742639  0.149623  -1.021435   0.032113  -0.354221  -1.123174
# 16385 -1.742639  0.149623  -1.021435   0.032113  -0.354221  -1.123174
#
#        Feature_5  Feature_6     Class  Feature_7  ...  Feature_32  Feature_33  \
# ...

# %% [markdown]
# # Model fitting

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import warnings

# %%
# Assigning Independent variables class
x = df.drop('Target', axis=1)

# %%
# Create a StandardScaler object
scaler = StandardScaler()

x = scaler.fit_transform(x)

# %%
# Assigning target class
y=df['Target']

# %%
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # spliting data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=123)

# %% [markdown]
# # Testing the  Model for suitable and best accuracy

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd

# load data


# create a Random Forest classifier with 100 trees
rf = RandomForestClassifier(n_estimators=100, random_state=42)

# fit the model to the training data
rf.fit(x_train, y_train)

# predict the class labels for the testing set
y_pred = rf.predict(x_test)

# evaluate the model's accuracy
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)

# print the classification report
report = classification_report(y_test, y_pred)
print('Classification report:', report)
# Out:
# Accuracy: 0.8163514338010982
# Classification report:               precision    recall  f1-score   support
#
#            0       1.00      0.01      0.02       111
#            1       0.77      0.06      0.11       409
#            2       0.00      0.00      0.00         8
#            3       0.00      0.00      0.00        92
#            4       0.82      1.00      0.90      2658
#
#     accuracy                           0.82      3278
#    macro avg       0.52      0.21      0.20      3278
# weighted avg       0.79      0.82      0.74      3278
# C:\Users\admn\anaconda4\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # xgboost

# %%
import xgboost as xgb

# %%
# create a DMatrix for training and testing data
dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_test, label=y_test)

# set XGBoost parameters
params = {
    'objective': 'multi:softmax',
    'num_class': len(y.unique())
}

# train the model
num_rounds = 100
bst = xgb.train(params, dtrain, num_rounds)

# make predictions on the testing set
y_pred = bst.predict(dtest)

# evaluate the model's accuracy
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)

# print the classification report
report = classification_report(y_test, y_pred)
print('Classification report:', report)
# Out:
# Accuracy: 0.8154362416107382
# Classification report:               precision    recall  f1-score   support
#
#            0       0.50      0.03      0.05       111
#            1       0.60      0.12      0.20       409
#            2       0.00      0.00      0.00         8
#            3       0.33      0.05      0.09        92
#            4       0.82      0.98      0.90      2658
#
#     accuracy                           0.82      3278
#    macro avg       0.45      0.24      0.25      3278
# weighted avg       0.77      0.82      0.76      3278
# C:\Users\admn\anaconda4\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# create decision tree base estimator
base_estimator = DecisionTreeClassifier(max_depth=1)

# create AdaBoost model with 50 estimators
model = AdaBoostClassifier(base_estimator=base_estimator, n_estimators=50, random_state=42)

# train the model on the training set
model.fit(x_train, y_train)

# make predictions on the testing set
y_pred = model.predict(x_test)

# calculate accuracy score of the model
accuracy = accuracy_score(y_test, y_pred)

# print the accuracy score
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8032336790726052

# %% [markdown]
# # xgboost

# %%
# create XGBoost model
import xgboost as xgb
model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)

# train the model on the training set
model.fit(x_train, y_train)

# make predictions on the testing set
y_pred = model.predict(x_test)

# calculate accuracy score of the model
accuracy = accuracy_score(y_test, y_pred)

# print the accuracy score
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8154362416107382

# %% [markdown]
# # DecisionTreeClassifier

# %%
# create Decision Tree Classifier model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=42)

# train the model on the training set
model.fit(x_train, y_train)

# make predictions on the testing set
y_pred = model.predict(x_test)

# calculate accuracy score of the model
accuracy = accuracy_score(y_test, y_pred)

# print the accuracy score
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6863941427699817

# %% [markdown]
# # KNeighborsClassifier

# %%
# training a KNN classifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 7).fit(x_train, y_train)
  
# accuracy on X_test
accuracy = knn.score(x_test, y_test)
  
# creating a confusion matrix
knn_predictions = knn.predict(x_test) 
cm = confusion_matrix(y_test, knn_predictions)
accuracy
# Out:
# C:\Users\admn\anaconda4\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# Creating the base classifier
base_clf = DecisionTreeClassifier()

# Creating the bagging classifier
bagging_clf = BaggingClassifier(base_estimator=base_clf, n_estimators=10, random_state=42)

# Training the bagging classifier
bagging_clf.fit(x_train, y_train)

# Predicting the test set labels
y_pred = bagging_clf.predict(x_test)

# Evaluating the bagging classifier accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Bagging classifier accuracy:", accuracy)
# Out:
# Bagging classifier accuracy: 0.7910311165344722

# %% [markdown]
# # Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# Creating the base classifier
base_clf = DecisionTreeClassifier(max_depth=1)

# Creating the AdaBoost classifier
ada_clf = AdaBoostClassifier(base_estimator=base_clf, n_estimators=50, random_state=42)

# Training the AdaBoost classifier
ada_clf.fit(x_train, y_train)

# Predicting the test set labels
y_pred = ada_clf.predict(x_test)

# Evaluating the AdaBoost classifier accuracy
accuracy = accuracy_score(y_test, y_pred)
print("AdaBoost classifier accuracy:", accuracy)
# Out:
# AdaBoost classifier accuracy: 0.8032336790726052

# %% [markdown]
# # Hypertuning

# %% [markdown]
# # Grid Search

# %%
# Splitting the data into features and target
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
X = df.drop('Target', axis=1)
y = df['Target']

# Scaling the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Defining the hyperparameter grid for logistic regression
params = {'C': [0.1, 1, 100], 'penalty': ['l1', 'l2'], 'solver': ['liblinear']}

# Creating the logistic regression model
logreg = LogisticRegression(multi_class='auto', max_iter=500)

# Creating the GridSearchCV object
grid_search = GridSearchCV(logreg, param_grid=params, cv=5)

# Fitting the GridSearchCV object to the data
grid_search.fit(X_scaled, y)

# Printing the best parameters and score
print("Best parameters: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)
# Out:
# Best parameters:  {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
# Best score:  0.803856970476464

# %% [markdown]
# # Conclusion

# %% [markdown]
# For the data set the Random forest  perofoming well with 82 %
#
# Xboost, Adaboost, Bagging , grid search of Logistic regresssion about 80%
#
#  Decision tree 69% which is least
